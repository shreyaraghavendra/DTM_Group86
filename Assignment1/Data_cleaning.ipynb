# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Setting Pandas Display Options
pd.set_option('display.max_rows', 200) 
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv('dataset_mood_smartphone.csv')

# %% [markdown]
# ## Data Sorting and Exploration

# %%
# Storing each attribute in a seperate column
counts = df.groupby(['id', 'variable']).size().unstack()
# print(counts)
pivot = df.pivot_table(index=['id', 'time'], columns='variable', values='value').reset_index()
pivot
# Out:
# variable       id                     time  activity  appCat.builtin  \
# 0         AS14.01  2014-02-17 12:04:42.394       NaN             NaN
# 1         AS14.01  2014-02-17 18:28:25.520       NaN             NaN
# 2         AS14.01  2014-02-18 09:29:51.257       NaN             NaN
# 3         AS14.01  2014-02-19 14:43:30.575       NaN             NaN
# 4         AS14.01  2014-02-19 17:29:10.378       NaN             NaN
# ...           ...                      ...       ...             ...
# 358921    AS14.33  2014-05-30 22:32:05.016       NaN             NaN
# 358922    AS14.33  2014-05-30 22:32:11.049       NaN           3.122
# 358923    AS14.33  2014-05-30 22:32:14.240       NaN           1.003
# 358924    AS14.33  2014-05-30 22:32:15.246       NaN           4.134
# 358925    AS14.33  2014-05-31 12:00:00.000       NaN             NaN
#
# variable  appCat.communication  appCat.entertainment  appCat.finance  \
# 0                          NaN                   NaN             NaN
# 1                          NaN                   NaN             NaN
# 2                          NaN                   NaN             NaN
# 3                          NaN                   NaN             NaN
# 4                          NaN                   NaN             NaN
# ...                        ...                   ...             ...
# 358921                     NaN                   NaN             NaN
# 358922                     NaN                   NaN             NaN
# 358923                     NaN                   NaN             NaN
# 358924                     NaN                   NaN             NaN
# 358925                     NaN                   NaN             NaN
#
# variable  appCat.game  appCat.office  appCat.other  appCat.social  \
# 0                 NaN            NaN           NaN            NaN
# 1                 NaN            NaN           NaN            NaN
# 2                 NaN            NaN           NaN            NaN
# 3                 NaN            NaN           NaN            NaN
# 4                 NaN            NaN           NaN            NaN
# ...               ...            ...           ...            ...
# 358921            NaN            NaN           NaN            NaN
# 358922            NaN            NaN           NaN            NaN
# 358923            NaN            NaN           NaN            NaN
# 358924            NaN            NaN           NaN            NaN
# 358925            NaN            NaN           NaN            NaN
#
# variable  appCat.travel  appCat.unknown  appCat.utilities  appCat.weather  \
# 0                   NaN             NaN               NaN             NaN
# 1                   NaN             NaN               NaN             NaN
# 2                   NaN             NaN               NaN             NaN
# 3                   NaN             NaN               NaN             NaN
# 4                   NaN             NaN               NaN             NaN
# ...                 ...             ...               ...             ...
# 358921              NaN             NaN             6.019             NaN
# 358922              NaN             NaN               NaN             NaN
# 358923              NaN             NaN               NaN             NaN
# 358924              NaN             NaN               NaN             NaN
# 358925              NaN             NaN               NaN             NaN
#
# variable  call  circumplex.arousal  circumplex.valence  mood  screen  sms
# 0          1.0                 NaN                 NaN   NaN     NaN  NaN
# 1          1.0                 NaN                 NaN   NaN     NaN  NaN
# 2          1.0                 NaN                 NaN   NaN     NaN  NaN
# 3          1.0                 NaN                 NaN   NaN     NaN  NaN
# 4          1.0                 NaN                 NaN   NaN     NaN  NaN
# ...        ...                 ...                 ...   ...     ...  ...
# 358921     NaN                 NaN                 NaN   NaN     NaN  NaN
# 358922     NaN                 NaN                 NaN   NaN     NaN  NaN
# 358923     NaN                 NaN                 NaN   NaN     NaN  NaN
# 358924     NaN                 NaN                 NaN   NaN     NaN  NaN
# 358925     NaN                -2.0                 1.0   7.0     NaN  NaN
#
# [358926 rows x 21 columns]

# %%
pivot.describe()
# Out:
# variable      activity  appCat.builtin  appCat.communication  \
# count     22965.000000    91288.000000          74276.000000
# mean          0.115958       18.538262             43.343792
# std           0.186946      415.989243            128.912750
# min           0.000000   -82798.871000              0.006000
# 25%           0.000000        2.020000              5.218000
# 50%           0.021739        4.038000             16.225500
# 75%           0.158333        9.922000             45.475750
# max           1.000000    33960.246000           9830.777000
#
# variable  appCat.entertainment  appCat.finance  appCat.game  appCat.office  \
# count             27125.000000      939.000000   813.000000    5642.000000
# mean                 37.576480       21.755251   128.391615      22.578892
# std                 262.960476       39.218361   327.145246     449.601382
# min                  -0.011000        0.131000     1.003000       0.003000
# 25%                   1.334000        4.072000    14.148000       2.004000
# 50%                   3.391000        8.026000    43.168000       3.106000
# 75%                  14.922000       20.155000   123.625000       8.043750
# max               32148.677000      355.513000  5491.793000   32708.818000
#
# variable  appCat.other  appCat.social  appCat.travel  appCat.unknown  \
# count      7650.000000   19145.000000    2846.000000      939.000000
# mean         25.810839      72.401906      45.730850       45.553006
# std         112.781355     261.551846     246.109307      119.400405
# min           0.014000       0.094000       0.080000        0.111000
# 25%           7.019000       9.030000       5.086500        5.018000
# 50%          10.028000      28.466000      18.144000       17.190000
# 75%          16.829250      75.372000      47.227250       44.430500
# max        3892.038000   30000.906000   10452.615000     2239.937000
#
# variable  appCat.utilities  appCat.weather    call  circumplex.arousal  \
# count          2487.000000      255.000000  5239.0         5582.000000
# mean             18.537552       20.148714     1.0           -0.098173
# std              60.959134       24.943431     0.0            1.051164
# min               0.246000        1.003000     1.0           -2.000000
# 25%               3.158500        8.684000     1.0           -1.000000
# 50%               8.030000       15.117000     1.0            0.000000
# 75%              19.331000       25.349000     1.0            1.000000
# max            1802.649000      344.863000     1.0            2.000000
#
# variable  circumplex.valence         mood        screen     sms
# count            5474.000000  5628.000000  96578.000000  1798.0
# mean                0.688893     6.993870     75.335206     1.0
# std                 0.670048     1.031496    253.822497     0.0
# min                -2.000000     1.000000      0.035000     1.0
# 25%                 0.000000     7.000000      5.322250     1.0
# 50%                 1.000000     7.000000     20.044500     1.0
# 75%                 1.000000     8.000000     62.540250     1.0
# max                 2.000000    10.000000   9867.007000     1.0

# %%
pivot.hist(bins = 30, figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'activity'}>,
#         <Axes: title={'center': 'appCat.builtin'}>,
#         <Axes: title={'center': 'appCat.communication'}>,
#         <Axes: title={'center': 'appCat.entertainment'}>],
#        [<Axes: title={'center': 'appCat.finance'}>,
#         <Axes: title={'center': 'appCat.game'}>,
#         <Axes: title={'center': 'appCat.office'}>,
#         <Axes: title={'center': 'appCat.other'}>],
#        [<Axes: title={'center': 'appCat.social'}>,
#         <Axes: title={'center': 'appCat.travel'}>,
#         <Axes: title={'center': 'appCat.unknown'}>,
#         <Axes: title={'center': 'appCat.utilities'}>],
#        [<Axes: title={'center': 'appCat.weather'}>,
#         <Axes: title={'center': 'call'}>,
#         <Axes: title={'center': 'circumplex.arousal'}>,
#         <Axes: title={'center': 'circumplex.valence'}>],
#        [<Axes: title={'center': 'mood'}>,
#         <Axes: title={'center': 'screen'}>,
#         <Axes: title={'center': 'sms'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ## Outlier Detection and Removal
# Paper: https://www.sciencedirect.com/science/article/pii/S1574013720304068

# %%
def plot_outliers_scatter(df, nrows, ncols, categories): 
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(12, 12))  
    for i in range(nrows):
        for j in range(ncols):
            category_index = i * 3 + j  # Calculate the index for accessing categories list
            category_name = categories[category_index]  # Get the category name
            
            axes[i, j].scatter(df['id'], df[category_name])
            axes[i, j].set_xlabel('id', fontweight='bold')
            axes[i, j].set_ylabel(category_name, fontweight='bold')

    plt.tight_layout()
    plt.show()

categories = ['appCat.communication', 'appCat.entertainment', 'appCat.social', 'appCat.finance',
                'appCat.game', 'appCat.office', 'appCat.social', 'appCat.travel', 'appCat.weather',
                'appCat.builtin', 'appCat.utilities', 'appCat.other', 'appCat.unknown', 'screen','mood']

plot_outliers_scatter(pivot, 5, 3, categories)

# %%
def remove_outliers_iqr(df, columns, multiplier=1.5):
    """
    Removes outliers from a dataframe based on the IQR method.
    
    Parameters:
    - df: pandas DataFrame.
    - columns: list of columns to check for outliers.
    - multiplier: the multiplier for the IQR to adjust strictness.
    
    Returns:
    - DataFrame with outliers set to None.
    """
    df_outliers_removed = df.copy()
    bounds = {}
    
    for column in columns:
        Q1 = df_outliers_removed[column].quantile(0.25)
        Q3 = df_outliers_removed[column].quantile(0.75)
        IQR = Q3 - Q1

        lower_bound = Q1 - (multiplier * IQR)
        upper_bound = Q3 + (multiplier * IQR)
        
        df_outliers_removed[column] = df[column].apply(lambda x: x if x >= lower_bound and x <= upper_bound else None)
        bounds[column] = (lower_bound, upper_bound)
    
    return df_outliers_removed, bounds

columns_to_check = ['appCat.communication', 'appCat.entertainment', 'appCat.social', 'appCat.finance',
                'appCat.game', 'appCat.office', 'appCat.social', 'appCat.travel', 'appCat.weather',
                'appCat.builtin', 'appCat.utilities', 'appCat.other', 'appCat.unknown', 'screen']

# %%
df_cleaned, outlier_bounds = remove_outliers_iqr(pivot, columns_to_check, 70)
plot_outliers_scatter(df_cleaned, 5, 3, columns_to_check)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 df_cleaned, outlier_bounds = remove_outliers_iqr(pivot, columns_to_check, 70)
# ----> 2 plot_outliers_scatter(df_cleaned, 5, 3, columns_to_check)
#
# Cell In[7], line 6, in plot_outliers_scatter(df, nrows, ncols, categories)
#       4 for j in range(ncols):
#       5     category_index = i * 3 + j  # Calculate the index for accessing categories list
# ----> 6     category_name = categories[category_index]  # Get the category name
#       8     axes[i, j].scatter(df['id'], df[category_name])
#       9     axes[i, j].set_xlabel('id', fontweight='bold')
#
# IndexError: list index out of range

# %% [markdown]
# ## Average all recordings of all attributes taken in one day

# %%
df_cleaned['time'] = pd.to_datetime(df_cleaned['time']) #convert string to datetime
averaged_df = df_cleaned.groupby(['id', df_cleaned['time'].dt.date]).mean() # average all values taken on the same day
averaged_df = averaged_df.drop('time', axis=1)
averaged_df
# Out:
# variable            activity  appCat.builtin  appCat.communication  \
# id      time
# AS14.01 2014-02-17       NaN             NaN                   NaN
#         2014-02-18       NaN             NaN                   NaN
#         2014-02-19       NaN             NaN                   NaN
#         2014-02-20       NaN             NaN                   NaN
#         2014-02-21       NaN             NaN                   NaN
# ...                      ...             ...                   ...
# AS14.33 2014-05-27  0.012704        8.545776             59.382943
#         2014-05-28  0.103301        9.590398             37.238750
#         2014-05-29  0.169354        6.452161             54.388125
#         2014-05-30  0.192901       14.776845             46.412278
#         2014-05-31       NaN             NaN                   NaN
#
# variable            appCat.entertainment  appCat.finance  appCat.game  \
# id      time
# AS14.01 2014-02-17                   NaN             NaN          NaN
#         2014-02-18                   NaN             NaN          NaN
#         2014-02-19                   NaN             NaN          NaN
#         2014-02-20                   NaN             NaN          NaN
#         2014-02-21                   NaN             NaN          NaN
# ...                                  ...             ...          ...
# AS14.33 2014-05-27             62.347000             NaN          NaN
#         2014-05-28             43.907571             NaN          NaN
#         2014-05-29             68.369000             NaN          NaN
#         2014-05-30             37.174286             NaN          NaN
#         2014-05-31                   NaN             NaN          NaN
#
# variable            appCat.office  appCat.other  appCat.social  appCat.travel  \
# id      time
# AS14.01 2014-02-17            NaN           NaN            NaN            NaN
#         2014-02-18            NaN           NaN            NaN            NaN
#         2014-02-19            NaN           NaN            NaN            NaN
#         2014-02-20            NaN           NaN            NaN            NaN
#         2014-02-21            NaN           NaN            NaN            NaN
# ...                           ...           ...            ...            ...
# AS14.33 2014-05-27            NaN     17.835750      50.259100            NaN
#         2014-05-28      44.738625     27.891895      99.281685            NaN
#         2014-05-29            NaN      9.734000     198.880222       0.939000
#         2014-05-30            NaN     10.522000      75.390690      37.594571
#         2014-05-31            NaN           NaN            NaN            NaN
#
# variable            appCat.unknown  appCat.utilities  appCat.weather  call  \
# id      time
# AS14.01 2014-02-17             NaN               NaN             NaN   1.0
#         2014-02-18             NaN               NaN             NaN   1.0
#         2014-02-19             NaN               NaN             NaN   1.0
#         2014-02-20             NaN               NaN             NaN   1.0
#         2014-02-21             NaN               NaN             NaN   NaN
# ...                            ...               ...             ...   ...
# AS14.33 2014-05-27             NaN         18.724333             NaN   1.0
#         2014-05-28             NaN          5.111000             NaN   1.0
#         2014-05-29             NaN          1.599500             NaN   1.0
#         2014-05-30        2.690667         15.521667             NaN   1.0
#         2014-05-31             NaN               NaN             NaN   NaN
#
# variable            circumplex.arousal  circumplex.valence  mood      screen  \
# id      time
# AS14.01 2014-02-17                 NaN                 NaN   NaN         NaN
#         2014-02-18                 NaN                 NaN   NaN         NaN
#         2014-02-19                 NaN                 NaN   NaN         NaN
#         2014-02-20                 NaN                 NaN   NaN         NaN
#         2014-02-21                 NaN                 NaN   NaN         NaN
# ...                                ...                 ...   ...         ...
# AS14.33 2014-05-27           -0.600000                 0.4   6.2  113.607750
#         2014-05-28            0.000000                 1.2   8.2  113.657683
#         2014-05-29           -1.333333                 1.0   7.0  118.978033
#         2014-05-30           -0.800000                -0.4   6.8   86.342245
#         2014-05-31           -2.000000                 1.0   7.0         NaN
#
# variable            sms
# id      time
# AS14.01 2014-02-17  NaN
#         2014-02-18  NaN
#         2014-02-19  1.0
#         2014-02-20  1.0
#         2014-02-21  1.0
# ...                 ...
# AS14.33 2014-05-27  1.0
#         2014-05-28  1.0
#         2014-05-29  1.0
#         2014-05-30  NaN
#         2014-05-31  NaN
#
# [1973 rows x 19 columns]

# %%
df_reset = averaged_df.reset_index()
heatmap_df = df_reset.pivot(index='time', columns='id', values='mood')

# Set the background color to white for NaN values
sns.set_style("white")

# Create the heatmap
plt.figure(figsize=(10, 8))  # Adjust the size as needed
ax = sns.heatmap(heatmap_df, cmap="viridis", linewidths=.5, linecolor='gray', cbar_kws={'label': 'Mood'})

# Set the colors for NaN values to white
ax.set_facecolor('white')

plt.title('Heatmap of Mood by Day and ID')
plt.xlabel('ID')
plt.ylabel('Day')
plt.show()

# %%
# Set seaborn style for the plots
sns.set(style="white")

# List all variable names except 'id' and 'time' which are not to be plotted
variables = [col for col in df_reset.columns if col not in ['id', 'time']]

# Prepare for plotting
num_variables = len(variables)
num_rows = -(-num_variables // 5)  # Ceiling division to calculate the number of rows needed
fig, axs = plt.subplots(num_rows, 5, figsize=(20, num_rows * 4))  # Adjust figsize as needed

# Flatten the axs array for easy iteration
axs = axs.flatten()

for i, var in enumerate(variables):
    # Pivot the table for the current variable
    heatmap_df = df_reset.pivot(index='time', columns='id', values=var)
    
    # Plot the heatmap
    sns.heatmap(heatmap_df, ax=axs[i], cmap="viridis", cbar_kws={'label': var}, linewidths=.5, linecolor='gray')
    axs[i].set_title(var)
    axs[i].set_facecolor('white')  # Set the background color for NaN values to white

# Hide any unused subplots that might exist if the number of variables is not a multiple of 5
for j in range(i + 1, num_rows * 5):
    axs[j].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Remove attributes with mostly NaN values

# %%
df_reset = df_reset.drop(['appCat.finance', 'appCat.game', 'appCat.office', 'appCat.travel', 
                         'appCat.weather', 'appCat.utilities', 'appCat.unknown'], axis=1)

# %% [markdown]
# ## Keep only days where 6 or more people have data for 'mood'

# %%
mood_counts = df_reset.groupby('time')['mood'].count()
days_with_sufficient_mood_data = mood_counts[mood_counts >= 6].index

# Filter the original DataFrame to keep only rows where 'day' is in days_with_sufficient_mood_data
df_filtered = df_reset[df_reset['time'].isin(days_with_sufficient_mood_data)]
df_filtered
# Out:
# variable       id        time  activity  appCat.builtin  appCat.communication  \
# 19        AS14.01  2014-03-14       NaN             NaN                   NaN
# 20        AS14.01  2014-03-15       NaN             NaN                   NaN
# 21        AS14.01  2014-03-16       NaN             NaN                   NaN
# 22        AS14.01  2014-03-17       NaN             NaN                   NaN
# 23        AS14.01  2014-03-18       NaN             NaN                   NaN
# ...           ...         ...       ...             ...                   ...
# 1952      AS14.33  2014-05-11  0.011163        3.609625             36.039214
# 1953      AS14.33  2014-05-12  0.024017        7.989216             71.059000
# 1954      AS14.33  2014-05-13  0.139964       18.559481            117.318162
# 1955      AS14.33  2014-05-14  0.003986        6.113182             26.813667
# 1956      AS14.33  2014-05-15  0.122531       11.082949             46.312440
#
# variable  appCat.entertainment  appCat.other  appCat.social  call  \
# 19                         NaN           NaN            NaN   1.0
# 20                         NaN           NaN            NaN   NaN
# 21                         NaN           NaN            NaN   NaN
# 22                         NaN           NaN            NaN   NaN
# 23                         NaN           NaN            NaN   1.0
# ...                        ...           ...            ...   ...
# 1952                 29.803083     10.710200     109.340632   NaN
# 1953                 59.354500     48.872167      96.132548   1.0
# 1954                102.675250     13.182667      70.495191   1.0
# 1955                136.701750     14.423000     220.868941   NaN
# 1956                 43.555706     13.175500      83.541541   1.0
#
# variable  circumplex.arousal  circumplex.valence      mood      screen  sms
# 19                       NaN                 NaN       NaN         NaN  1.0
# 20                       NaN                 NaN       NaN         NaN  1.0
# 21                       NaN                 NaN       NaN         NaN  1.0
# 22                       NaN                 NaN       NaN         NaN  1.0
# 23                       NaN                 NaN       NaN         NaN  1.0
# ...                      ...                 ...       ...         ...  ...
# 1952                0.000000                 0.4  6.000000  144.225784  NaN
# 1953               -0.750000                 0.5  6.000000  210.002483  NaN
# 1954                0.500000                 0.0  5.000000  147.320176  NaN
# 1955               -0.333333                 0.4  6.833333  244.069353  NaN
# 1956                0.000000                 0.5  6.000000  115.095551  1.0
#
# [1414 rows x 14 columns]

# %%
heatmap_df = df_filtered.pivot(index='time', columns='id', values='mood')

# Set the background color to white for NaN values
sns.set_style("white")

# Create the heatmap
plt.figure(figsize=(10, 8))  # Adjust the size as needed
ax = sns.heatmap(heatmap_df, cmap="viridis", linewidths=.5, linecolor='gray', cbar_kws={'label': 'Mood'})

# Set the colors for NaN values to white
ax.set_facecolor('white')

plt.title('Heatmap of Mood by Day and ID')
plt.xlabel('ID')
plt.ylabel('Day')
plt.show()

# %%
df_filtered.to_csv('data_cleaned.csv', index=False)
